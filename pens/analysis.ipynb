# %%
import pandas as pd

# %%
df = pd.read_csv('pens_all_pages.csv')
df
# Out:
#                                         product_title          product_id  \
# 0                                           Gift Card                 GFT
# 1            Clairefontaine Kenzo A5 Notebook - Lined          CF-115902C
# 2                         Col-o-ring Ink Testing Book            CO-10001
# 3       Pilot Metropolitan Fountain Pen - Black Plain             PN91111
# 4                      TWSBI ECO Fountain Pen - Clear         TW-M7445300
# 5                Platinum Preppy Fountain Pen - Black   Plat-PSQ-400-01-1
# 6                      TWSBI ECO Fountain Pen - Black         TW-M7444280
# 7            Noodler's Ahab Flex Fountain Pen - Clear              N15021
# 8                 LAMY safari Fountain Pen - charcoal           LMY-L17EF
# 9              TWSBI Diamond 580 Fountain Pen - Clear         TW-M7443110
# 10                Platinum Preppy Fountain Pen - Blue   Plat-PSQ-400-03-1
# 11                     TWSBI ECO Fountain Pen - White         TW-M7444330
# ...
